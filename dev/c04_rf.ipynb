# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Useful-Scripts" data-toc-modified-id="Useful-Scripts-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Useful Scripts</a></span></li><li><span><a href="#Load-the-data" data-toc-modified-id="Load-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load the data</a></span></li><li><span><a href="#Random-Forest-Modelling" data-toc-modified-id="Random-Forest-Modelling-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Random Forest Modelling</a></span></li><li><span><a href="#Grid-Search" data-toc-modified-id="Grid-Search-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Grid Search</a></span></li><li><span><a href="#Use-the-best-parameters-from-grid-search" data-toc-modified-id="Use-the-best-parameters-from-grid-search-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Use the best parameters from grid search</a></span></li><li><span><a href="#Randomized-search" data-toc-modified-id="Randomized-search-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Randomized search</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Feature-Importance-using-eli5" data-toc-modified-id="Feature-Importance-using-eli5-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Feature Importance using eli5</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Kernel Author:</b>  <br>
# <a href="https://bhishanpdl.github.io/" , target="_blank">Bhishan Poudel,  Data Scientist, Ph.D Astrophysics</a> .
# </div>

# %% [markdown]
# # Imports

# %%
import time
time_start_notebook = time.time()

# usual imports
import numpy as np
import pandas as pd

import os
import time
import collections
import itertools
import six
import pickle
import joblib

# random state
SEED=100
np.random.seed(SEED) # we need this in each cell

# sklearn
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# versions
import watermark
# %load_ext watermark
# %watermark -a "Bhishan Poudel" -d -v -m
print()
# %watermark -iv
# Out:
# Bhishan Poudel 2020-11-02
#
# CPython 3.7.7
# IPython 7.18.1
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
#
# six       1.15.0
# sklearn   0.23.1
# watermark 2.0.2
# numpy     1.18.4
# pandas    1.1.0
# joblib    0.17.0

# %% [markdown]
# # Useful Scripts

# %%
def show_methods(obj, ncols=7,start=None, inside=None):
    """ Show all the attributes of a given method.
    Example:
    ========
    show_method_attributes(list)
     """
    lst = [elem for elem in dir(obj) if elem[0]!='_' ]
    lst = [elem for elem in lst 
           if elem not in 'os np pd sys time psycopg2'.split() ]

    if isinstance(start,str):
        lst = [elem for elem in lst if elem.startswith(start)]
        
    if isinstance(start,tuple) or isinstance(start,list):
        lst = [elem for elem in lst for start_elem in start
               if elem.startswith(start_elem)]
        
    if isinstance(inside,str):
        lst = [elem for elem in lst if inside in elem]
        
    if isinstance(inside,tuple) or isinstance(inside,list):
        lst = [elem for elem in lst for inside_elem in inside
               if inside_elem in elem]

    return pd.DataFrame(np.array_split(lst,ncols)).T.fillna('')

def adjustedR2(rsquared,nrows,kcols):
    return rsquared- (kcols-1)/(nrows-kcols) * (1-rsquared)


def multiple_linear_regression(df,features,target,model,
                               verbose=1,cv=5,test_size=0.3):
    """ Multiple Linear Regression Modelling using given model.
    
    Depends:
    Depends on function adjusted r-squared.
    
    
    Returns:
    rmse, r2_train, ar2_train, r2_test, ar2_test, cv
    """
    
    # train test split
    train, test = train_test_split(df, test_size=0.2, random_state=100)

    # train test values
    X = df[features].values
    y = df[target].values.ravel()

    Xtrain = train[features].values
    ytrain = train[target].values.ravel()

    Xtest = test[features].values
    ytest = test[target].values.ravel()
    
    # fitting
    model.fit(Xtrain,ytrain)

    # prediction
    ypreds = model.predict(Xtest)

    # metrics
    rmse = np.sqrt(mean_squared_error(ytest,ypreds)).round(3)
    r2_train = model.score(Xtrain, ytrain).round(3)
    r2_test = model.score(Xtest, ytest).round(3)

    cv = cross_val_score(model, X, y, cv=5,n_jobs=-1,
                         verbose=verbose).mean().round(3)

    ar2_train = adjustedR2(model.score(Xtrain,ytrain),
                           Xtrain.shape[0],
                           len(features)).round(3)
    ar2_test  = adjustedR2(model.score(Xtest,ytest),
                           Xtest.shape[0] ,
                           len(features)).round(3)
    
    return (rmse, r2_train, ar2_train, r2_test, ar2_test, cv)


df_eval = pd.DataFrame({'Model': [],
                           'Details':[],
                           'Root Mean Squared Error (RMSE)':[],
                           'R-squared (training)':[],
                           'Adjusted R-squared (training)':[],
                           'R-squared (test)':[],
                           'Adjusted R-squared (test)':[],
                           '5-Fold Cross Validation':[]})

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv('../data/raw/kc_house_data.csv')
df.drop(['id','date'],axis=1,inplace=True)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062
# 3    98136  47.5208 -122.393           1360        5000
# 4    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# # Random Forest Modelling

# %%
target = ['price']
features = df.drop(['price'],axis=1).columns

# %%
model = RandomForestRegressor(n_estimators= 50,random_state=SEED)

rmse, r2_train, ar2_train, r2_test, ar2_test, cv = \
    multiple_linear_regression(df, features, target,model,
                               verbose=0,test_size=0.2)


df_eval.loc[len(df_eval)] = ['Random Forest Regressor',
                             '', rmse,r2_train,ar2_train,
                             r2_test,ar2_test,cv]


df_eval
# Out:
#                      Model Details  Root Mean Squared Error (RMSE)  \
# 0  Random Forest Regressor                              125316.711
#
#    R-squared (training)  Adjusted R-squared (training)  R-squared (test)  \
# 0                 0.981                          0.981             0.883
#
#    Adjusted R-squared (test)  5-Fold Cross Validation
# 0                      0.883                    0.872

# %% [markdown]
# # Grid Search
#
# Most important hyperparameters of Random Forest:
#
# - n_estimators = n of trees
# - max_features = max number of features considered for splitting a node
# - max_depth = max number of levels in each decision tree
# - min_samples_split = min number of data points placed in a node before the node is split
# - min_samples_leaf = min number of data points allowed in a leaf node
# - bootstrap = method for sampling data points (with or without replacement)

# %%
# train test split
train, test = train_test_split(df, test_size=0.2, random_state=SEED)

# train test values
X = df[features].values
y = df[target].values.ravel()

Xtrain = train[features].values
ytrain = train[target].values.ravel()

Xtest = test[features].values
ytest = test[target].values.ravel()

# %%
# %%time
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor(random_state=SEED,n_jobs=-1)


param_grid = [
{'n_estimators': np.arange(20,100,10),
 'max_features': ['sqrt', 'auto', len(features)], 
 'max_depth': [10, 50, None],
 'min_samples_split': [2,5,10],
 'min_samples_leaf': [1,2,4],
 'bootstrap': [True, False]}
]

param_grid = [{
 'n_estimators': [500]
}]

grid_search_forest = GridSearchCV(model,
                                  param_grid,
                                  cv=5,
                                  n_jobs=-1,
                                  scoring='neg_mean_squared_error',
                                  verbose=0)

grid_search_forest.fit(Xtrain, ytrain)
# this takes very long time, comment this after use
# save the pickled result and load the pickle.
# Out:
# CPU times: user 1min 15s, sys: 474 ms, total: 1min 15s
# Wall time: 1min 57s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1, random_state=100),
#              n_jobs=-1, param_grid=[{'n_estimators': [500]}],
#              scoring='neg_mean_squared_error')

# %%
import pickle

with open('../models/grid_search_rf.pkl','wb') as fo:
    pickle.dump(grid_search_forest, fo)

# %% [markdown]
# # Use the best parameters from grid search

# %%
show_methods(grid_search_forest)
# Out:
#                  0                  1                  2               3  \
# 0  best_estimator_                 cv                fit  n_features_in_
# 1      best_index_        cv_results_         get_params          n_jobs
# 2     best_params_  decision_function                iid       n_splits_
# 3      best_score_        error_score  inverse_transform      param_grid
# 4         classes_          estimator       multimetric_    pre_dispatch
#
#                    4                   5           6
# 0            predict         refit_time_     scoring
# 1  predict_log_proba  return_train_score  set_params
# 2      predict_proba               score   transform
# 3              refit             scorer_     verbose
# 4

# %%
df_gs_rf = pd.DataFrame(grid_search_forest.cv_results_)
df_gs_rf.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_n_estimators', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %%
# df_gs_rf param_max_features

# %%
# df_gs_rf.pivot_table(
#     index=['param_max_features','param_n_estimators'],
#     columns=['param_bootstrap','param_max_depth'],
#     values='mean_test_score').round(2)\
# .style.background_gradient('Blues',axis=None)

# %%
grid_search_forest.best_params_
# Out:
# {'n_estimators': 500}

# %%
grid_search_forest.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=100)

# %%
model = RandomForestRegressor(n_estimators= 40,random_state=SEED,
                max_features=18, max_depth=50, bootstrap=True)

rmse, r2_train, ar2_train, r2_test, ar2_test, cv = \
    multiple_linear_regression(df, features, target,model,
                               verbose=0,test_size=0.2)

df_eval.loc[len(df_eval)] = ['Random Forest Regressor after grid search',
                             '', rmse,r2_train,ar2_train,
                             r2_test,ar2_test,cv]


df_eval.sort_values('Adjusted R-squared (test)')
# Out:
#                                        Model Details  \
# 0                    Random Forest Regressor
# 1  Random Forest Regressor after grid search
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                      125316.711                 0.981
# 1                      125118.269                 0.981
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 0                          0.981             0.883                      0.883
# 1                          0.981             0.884                      0.883
#
#    5-Fold Cross Validation
# 0                    0.872
# 1                    0.872

# %% [markdown]
# # Randomized search

# %%
from sklearn.model_selection import RandomizedSearchCV
from pprint import pprint

# Number of trees in  forest
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 200, num = 5)]

# max features
max_features = ['auto', 'sqrt']

# max depth of leaves
max_depth = [int(x) for x in np.linspace(1, 45, num = 3)]

# min samples split
min_samples_split = [5, 10]

# random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split}


random_grid = {'n_estimators': [500]}

pprint(random_grid)
# Out:
# {'n_estimators': [500]}

# %%
rf_random = RandomizedSearchCV(estimator = model,
                               param_distributions = random_grid,
                               n_iter = 10,
                               cv = 5,
                               verbose=2,
                               random_state=SEED,
                               n_jobs = -1,
                               scoring='neg_mean_squared_error')
# Fit the random search model
rf_random.fit(Xtrain, ytrain)
# Out:
# /Users/poudel/opt/miniconda3/envs/dataSc/lib/python3.7/site-packages/sklearn/model_selection/_search.py:282: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.9min finished
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestRegressor(max_depth=50,
#                                                    max_features=18,
#                                                    n_estimators=40,
#                                                    random_state=100),
#                    n_jobs=-1, param_distributions={'n_estimators': [500]},
#                    random_state=100, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 500}

# %%
model = RandomForestRegressor(n_estimators= 155,
                              random_state=SEED,
                              max_features='auto',
                              max_depth=23,
                              min_samples_split=10)

rmse, r2_train, ar2_train, r2_test, ar2_test, cv = \
    multiple_linear_regression(df, features, target,model,
                               verbose=0,test_size=0.2)


df_eval.loc[len(df_eval)] = ['Random Forest Regressor after grid search',
                             '', rmse,r2_train,ar2_train,
                             r2_test,ar2_test,cv]

df_eval.sort_values('Adjusted R-squared (test)')
# Out:
#                                        Model Details  \
# 2  Random Forest Regressor after grid search
# 0                    Random Forest Regressor
# 1  Random Forest Regressor after grid search
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 2                      126117.377                 0.960
# 0                      125316.711                 0.981
# 1                      125118.269                 0.981
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 2                          0.960             0.882                      0.882
# 0                          0.981             0.883                      0.883
# 1                          0.981             0.884                      0.883
#
#    5-Fold Cross Validation
# 2                    0.874
# 0                    0.872
# 1                    0.872

# %% [markdown]
# # Feature Importance

# %%
importances = rf_random.best_estimator_.feature_importances_
importances
# Out:
# array([0.00336207, 0.0095678 , 0.25321646, 0.0138223 , 0.00199991,
#        0.03340136, 0.01121503, 0.00305515, 0.32698117, 0.02165846,
#        0.00540681, 0.02714913, 0.00198656, 0.01485976, 0.1570932 ,
#        0.0693733 , 0.03159132, 0.01426019])

# %%
df_imp = pd.DataFrame({'feature': features,
                      'importance': importances})

df_imp.sort_values('importance', ascending=False)\
  .style.background_gradient(subset=['importance'])
# Out:
# <style  type="text/css" >
# #T_a4876ede_1d40_11eb_a908_acde48001122row0_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row1_col1{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row2_col1{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row3_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row4_col1{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row5_col1{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row6_col1{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row7_col1{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row8_col1{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row9_col1,#T_a4876ede_1d40_11eb_a908_acde48001122row10_col1{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row11_col1{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row12_col1{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row13_col1{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row14_col1{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_a4876ede_1d40_11eb_a908_acde48001122row15_col1,#T_a4876ede_1d40_11eb_a908_acde48001122row16_col1,#T_a4876ede_1d40_11eb_a908_acde48001122row17_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_a4876ede_1d40_11eb_a908_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >feature</th>        <th class="col_heading level0 col1" >importance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row0_col0" class="data row0 col0" >grade</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row0_col1" class="data row0 col1" >0.326981</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row1_col0" class="data row1 col0" >sqft_living</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row1_col1" class="data row1 col1" >0.253216</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row2" class="row_heading level0 row2" >14</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row2_col0" class="data row2 col0" >lat</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row2_col1" class="data row2 col1" >0.157093</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row3_col0" class="data row3 col0" >long</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row3_col1" class="data row3 col1" >0.069373</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row4_col0" class="data row4 col0" >waterfront</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row4_col1" class="data row4 col1" >0.033401</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row5" class="row_heading level0 row5" >16</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row5_col0" class="data row5 col0" >sqft_living15</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row5_col1" class="data row5 col1" >0.031591</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row6" class="row_heading level0 row6" >11</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row6_col0" class="data row6 col0" >yr_built</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row6_col1" class="data row6 col1" >0.027149</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row7" class="row_heading level0 row7" >9</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row7_col0" class="data row7 col0" >sqft_above</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row7_col1" class="data row7 col1" >0.021658</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row8" class="row_heading level0 row8" >13</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row8_col0" class="data row8 col0" >zipcode</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row8_col1" class="data row8 col1" >0.014860</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row9" class="row_heading level0 row9" >17</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row9_col0" class="data row9 col0" >sqft_lot15</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row9_col1" class="data row9 col1" >0.014260</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row10" class="row_heading level0 row10" >3</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row10_col0" class="data row10 col0" >sqft_lot</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row10_col1" class="data row10 col1" >0.013822</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row11" class="row_heading level0 row11" >6</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row11_col0" class="data row11 col0" >view</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row11_col1" class="data row11 col1" >0.011215</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row12" class="row_heading level0 row12" >1</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row12_col0" class="data row12 col0" >bathrooms</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row12_col1" class="data row12 col1" >0.009568</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1d40_11eb_a908_acde48001122level0_row13" class="row_heading level0 row13" >10</th>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row13_col0" class="data row13 col0" >sqft_basement</td>
#                         <td id="T_a4876ede_1d40_11eb_a908_acde48001122row13_col1" class="data row13 col1" >0.005407</td>
#             </tr>
#             <tr>
#                         <th id="T_a4876ede_1

# %% [markdown]
# # Feature Importance using eli5

# %%
import eli5
from eli5.sklearn import PermutationImportance
from eli5 import show_prediction
# Out:
# /Users/poudel/opt/miniconda3/envs/dataSc/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/poudel/opt/miniconda3/envs/dataSc/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
perm = PermutationImportance(model, random_state=1).fit(Xtest, ytest)

eli5.show_weights(perm, feature_names = features.values.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3622
#
#                     &plusmn; 0.0170
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2656
#
#                     &plusmn; 0.0125
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_living
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2399
#
#                     &plusmn; 0.0115
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 grade
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1727
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 long
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0285
#
#                     &plusmn; 0.0042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 yr_built
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0276
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 waterfront
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0233
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_living15
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0134
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 zipcode
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_above
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 view
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0059
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_lot
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_lot15
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 condition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 yr_renovated
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bathrooms
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bedrooms
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0004
#
#                     &plusmn; 0.0003
#
#             </td>

# %%
eli5.explain_weights_df(perm, feature_names=features.values.tolist())\
  .style.background_gradient(subset=['weight'])
# Out:
# <style  type="text/css" >
# #T_aa5e5750_1d40_11eb_a908_acde48001122row0_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row1_col1{
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row2_col1{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row3_col1{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row4_col1{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row5_col1{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row6_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row7_col1{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row8_col1{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row9_col1{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row10_col1{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row11_col1{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_aa5e5750_1d40_11eb_a908_acde48001122row12_col1,#T_aa5e5750_1d40_11eb_a908_acde48001122row13_col1,#T_aa5e5750_1d40_11eb_a908_acde48001122row14_col1,#T_aa5e5750_1d40_11eb_a908_acde48001122row15_col1,#T_aa5e5750_1d40_11eb_a908_acde48001122row16_col1,#T_aa5e5750_1d40_11eb_a908_acde48001122row17_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_aa5e5750_1d40_11eb_a908_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >feature</th>        <th class="col_heading level0 col1" >weight</th>        <th class="col_heading level0 col2" >std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row0_col0" class="data row0 col0" >lat</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row0_col1" class="data row0 col1" >0.362158</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row0_col2" class="data row0 col2" >0.008484</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row1_col0" class="data row1 col0" >sqft_living</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row1_col1" class="data row1 col1" >0.265606</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row1_col2" class="data row1 col2" >0.006236</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row2_col0" class="data row2 col0" >grade</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row2_col1" class="data row2 col1" >0.239867</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row2_col2" class="data row2 col2" >0.005755</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row3_col0" class="data row3 col0" >long</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row3_col1" class="data row3 col1" >0.172746</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row3_col2" class="data row3 col2" >0.002020</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row4_col0" class="data row4 col0" >yr_built</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row4_col1" class="data row4 col1" >0.028458</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row4_col2" class="data row4 col2" >0.002106</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row5_col0" class="data row5 col0" >waterfront</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row5_col1" class="data row5 col1" >0.027558</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row5_col2" class="data row5 col2" >0.001078</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row6_col0" class="data row6 col0" >sqft_living15</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row6_col1" class="data row6 col1" >0.023341</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row6_col2" class="data row6 col2" >0.001480</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row7_col0" class="data row7 col0" >zipcode</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row7_col1" class="data row7 col1" >0.013418</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row7_col2" class="data row7 col2" >0.000977</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row8_col0" class="data row8 col0" >sqft_above</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row8_col1" class="data row8 col1" >0.008852</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row8_col2" class="data row8 col2" >0.000448</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row9_col0" class="data row9 col0" >view</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row9_col1" class="data row9 col1" >0.006840</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row9_col2" class="data row9 col2" >0.000507</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row10_col0" class="data row10 col0" >sqft_lot</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row10_col1" class="data row10 col1" >0.005868</td>
#                         <td id="T_aa5e5750_1d40_11eb_a908_acde48001122row10_col2" class="data row10 col2" >0.000558</td>
#             </tr>
#             <tr>
#                         <th id="T_aa5e5750_1d40_11eb_a908_acde

# %%
test.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 19836  285000.0         3        2.5         2437      5136     2.0
# 10442  239950.0         3        2.5         1560      4800     2.0
# 20548  460000.0         3        2.5         2390     47480     2.0
# 11014  397500.0         3        1.0         1480      5100     1.5
# 4138   545000.0         4        3.5         1880      1341     3.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 19836           0     0          3      7        2437              0
# 10442           0     0          4      7        1560              0
# 20548           0     0          3      9        2390              0
# 11014           0     0          3      7        1480              0
# 4138            0     0          3      8        1650            230
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 19836      2011             0    98002  47.3517 -122.210           2437
# 10442      1974             0    98001  47.2653 -122.285           1510
# 20548      2007             0    98058  47.4517 -122.084           1720
# 11014      1938          1959    98103  47.6915 -122.348           1300
# 4138       2007             0    98122  47.6053 -122.306           1740
#
#        sqft_lot15
# 19836        4614
# 10442       12240
# 20548       44866
# 11014        5100
# 4138         1883

# %%
eli5.show_prediction(model, test.iloc[0,1:],show_feature_values=True)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y
#
# </b>
#
#
#     (score <b>336570.214</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#                 <th style="padding: 0 0.5em 0 1em; text-align: right; border: none;">Value</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +539421.931
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +78412.938
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sqft_living
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2437.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10271.500
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sqft_living15
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2437.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.80%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9725.071
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         yr_built
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2011.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3725.560
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sqft_above
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2437.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +129.459
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         floors
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2.000
#         </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -31.142
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sqft_basement
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -36.586
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         yr_renovated
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -76.167
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         condition
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             3.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -411.935
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bedrooms
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             3.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -449.712
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bathrooms
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2.500
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1744.372
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         waterfront
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3436.990
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         zipcode
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             98002.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -5356.340
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         view
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -9126.177
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         long
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -122.210
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -9777.699
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %% [markdown]
# # Time Taken

# %%
time_taken = time.time() - time_start_notebook
h,m = divmod(time_taken,60*60)
print('Time taken to run whole notebook: {:.0f} hr '\
      '{:.0f} min {:.0f} secs'.format(h, *divmod(m,60)))
# Out:
# Time taken to run whole notebook: 0 hr 16 min 59 secs
