# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Load-the-libraries" data-toc-modified-id="Load-the-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load the libraries</a></span></li><li><span><a href="#Load-the-libraries" data-toc-modified-id="Load-the-libraries-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load the libraries</a></span></li><li><span><a href="#Useful-Functions" data-toc-modified-id="Useful-Functions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Useful Functions</a></span></li><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Load-the-Data" data-toc-modified-id="Load-the-Data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Load the Data</a></span></li><li><span><a href="#Modelling-Xgboost" data-toc-modified-id="Modelling-Xgboost-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Modelling Xgboost</a></span></li><li><span><a href="#Model-Evaluation-using-dalex" data-toc-modified-id="Model-Evaluation-using-dalex-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model Evaluation using dalex</a></span><ul class="toc-item"><li><span><a href="#Create-model-explainer" data-toc-modified-id="Create-model-explainer-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Create model explainer</a></span></li><li><span><a href="#DATASET-LEVEL" data-toc-modified-id="DATASET-LEVEL-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span><a href="https://pbiecek.github.io/ema/dataset-level.html" target="_blank">DATASET LEVEL</a></a></span><ul class="toc-item"><li><span><a href="#Model-Performance" data-toc-modified-id="Model-Performance-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span><a href="https://pbiecek.github.io/ema/modelPerformance.html" target="_blank">Model Performance</a></a></span></li><li><span><a href="#Variable-Importance-using:-model_parts" data-toc-modified-id="Variable-Importance-using:-model_parts-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span><a href="https://pbiecek.github.io/ema/featureImportance.html" target="_blank">Variable Importance using: model_parts</a></a></span></li><li><span><a href="#model_profile:-accumulated" data-toc-modified-id="model_profile:-accumulated-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>model_profile: accumulated</a></span></li><li><span><a href="#Model-Profile:-Partial-(pdp)" data-toc-modified-id="Model-Profile:-Partial-(pdp)-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Model Profile: Partial (pdp)</a></span></li><li><span><a href="#Model-Profile:-partial-with-categorical" data-toc-modified-id="Model-Profile:-partial-with-categorical-8.2.5"><span class="toc-item-num">8.2.5&nbsp;&nbsp;</span>Model Profile: partial with categorical</a></span></li></ul></li><li><span><a href="#INSTANCE-LEVEL" data-toc-modified-id="INSTANCE-LEVEL-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><a href="https://pbiecek.github.io/ema/InstanceLevelExploration.html" target="_blank">INSTANCE LEVEL</a></a></span><ul class="toc-item"><li><span><a href="#Predict" data-toc-modified-id="Predict-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Predict</a></span></li><li><span><a href="#Variable-Attribution-(predict_parts)" data-toc-modified-id="Variable-Attribution-(predict_parts)-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Variable Attribution (predict_parts)</a></span></li><li><span><a href="#-predict_profile:-Ceteris-Paribus-Profiles" data-toc-modified-id="-predict_profile:-Ceteris-Paribus-Profiles-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span><a href="https://pbiecek.github.io/ema/ceterisParibus.html" target="_blank"> predict_profile: Ceteris Paribus Profiles</a></a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Kernel Author:</b>  <br>
# <a href="https://bhishanpdl.github.io/" , target="_blank">Bhishan Poudel,  Data Scientist, Ph.D Astrophysics</a> .
# </div>

# %% [markdown]
# # Introduction
# Here, in this notebook I will use the model interpretation module [dalex](https://github.com/ModelOriented/DALEX) for the regression problem of house price prediction.

# %% [markdown]
# # Load the libraries

# %%
import time
time_start_notebook = time.time()

# %%
# %%capture
import os
import sys
ENV_COLAB = 'google.colab' in sys.modules

if ENV_COLAB:
    ## install modules
    # !pip install watermark
    # !pip install --upgrade dalex

    # if we update existing module, we need to restart colab
    # !pip install -U scikit-learn

    ## print
    print('Environment: Google Colaboratory.')
TREE_METHOD = 'gpu_hist' if ENV_COLAB else 'auto'

# %% [markdown]
# # Load the libraries

# %%
import numpy as np
import pandas as pd
import xgboost
import sklearn
from sklearn import metrics as skmetrics
import os
import joblib

# model eval
import dalex
import dalex as dx

# versions
import watermark
# %load_ext watermark
# %watermark -a "Bhishan Poudel" -d -v -m
print()
# %watermark -iv
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Bhishan Poudel 2020-11-22
#
# CPython 3.7.9
# IPython 7.18.1
#
# compiler   : Clang 10.0.0
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
#
# json      2.0.9
# dalex     0.4.0
# numpy     1.18.5
# sklearn   0.23.2
# xgboost   1.2.0
# watermark 2.0.2
# pandas    1.1.2
# joblib    0.16.0

# %% [markdown]
# # Useful Functions

# %%
def adjustedR2(rsquared,nrows,ncols):
    return rsquared- (ncols-1)/(nrows-ncols) * (1-rsquared)

def print_regr_eval(ytest,ypreds,ncols):
    rmse = np.sqrt(skmetrics.mean_squared_error(ytest,ypreds))
    r2 = skmetrics.r2_score(ytest,ypreds)
    ar2 = adjustedR2(r2,len(ytest),ncols)
    evs = skmetrics.explained_variance_score(ytest, ypreds)

    print(f"""
             RMSE : {rmse:,.2f}
Explained Variance: {evs:.6f}
         R-Squared: {r2:,.6f}
Adjusted R-squared: {ar2:,.6f}

""")
    
def show_methods(obj, ncols=4):
    lst = [i for i in dir(obj) if i[0]!='_' ]
    df = pd.DataFrame(np.array_split(lst,ncols)).T.fillna('')
    return df

# %% [markdown]
# # Parameters

# %%
if ENV_COLAB:
    path_git = 'https://raw.githubusercontent.com/bhishanpdl/Datasets/master/'
    project = 'Projects/King_County_Seattle_House_Price_Kaggle/'
    data_path_parent = path_git + project
else:
    data_path_parent = '../data/'

data_path_Xtest = data_path_parent + 'processed/Xtest.csv.zip'
data_path_ytest = data_path_parent + 'processed/ytest.csv'
target = 'price'
train_size = 0.8

print(data_path_Xtest)
# Out:
# ../data/processed/Xtest.csv.zip

# %% [markdown]
# # Load the Data

# %%
# Here, we only need test data
df_Xtest  = pd.read_csv(data_path_Xtest,compression='zip')
ser_ytest = pd.read_csv(data_path_ytest,header=None)
ytest  = np.array(ser_ytest).flatten()
features = list(df_Xtest.columns)

s = f"""
df_Xtest  = {df_Xtest.shape}
ytest     = {ytest.shape}

"""
print(s)

display(df_Xtest.head(2))
display(ser_ytest.head(2))

assert df_Xtest.shape[0] == ytest.shape[0]
# Out:
# df_Xtest  = (4323, 67)
# ytest     = (4323,)
#         age  age_after_renovation  age_after_renovation_cat  \
# 0 -1.372335             -1.316486                 -1.265291
# 1 -0.084817             -0.005269                 -0.062185
#
#    age_after_renovation_sq   age_cat    age_sq  basement_bool  bathrooms  \
# 0                -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 1                -0.285363 -0.139825 -0.348085      -0.801818   0.506258
#
#    bathrooms_sq  bedrooms  ...   view_sq  waterfront  waterfront_0  \
# 0      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
# 1      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
#
#    waterfront_1  waterfront_sq  yr_built  yr_renovated  yr_renovated2  \
# 0     -0.089698      -0.089698  1.361464     -0.207992       1.305630
# 1     -0.089698      -0.089698  0.107715     -0.207992       0.028586
#
#    yr_sales   zipcode
# 0 -0.693043 -1.422563
# 1  1.442912 -1.441324
#
# [2 rows x 67 columns]
#           0
# 0  285000.0
# 1  239950.0

# %% [markdown]
# # Modelling Xgboost

# %%
path_model_xgb = '../models/model_xgb_logtarget.dump'
model = xgboost.XGBRegressor()
model.load_model(path_model_xgb)

ypreds_log1p = model.predict(df_Xtest)
ypreds = np.expm1(ypreds_log1p)

print('ytest:', ytest[:3])
print('ypreds: ', ypreds[:3])
print_regr_eval(ytest,ypreds,df_Xtest.shape[1])
# Out:
# ytest: [285000. 239950. 460000.]
# ypreds:  [343218.4  204292.33 508420.8 ]
#
#              RMSE : 110,471.76
# Explained Variance: 0.910365
#          R-Squared: 0.909445
# Adjusted R-squared: 0.908041

# %% [markdown]
# # Model Evaluation using dalex
#
# ![](images/dalex_chart.png)

# %%
import dalex

# %%
show_methods(dalex)
# Out:
#            0              1               2         3
# 0      Arena  dataset_level        fairness  wrappers
# 1  Explainer       datasets  instance_level

# %% [markdown]
# ## Create model explainer

# %%
def predict_function(model, data):
    return np.expm1(model.predict(data))

# %%
exp = dx.Explainer(model, df_Xtest, ytest,
                  predict_function=predict_function,
                  label='xgboost')
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 4323 rows 67 cols
#   -> target variable   : 4323 values
#   -> model_class       : xgboost.sklearn.XGBRegressor (default)
#   -> label             : xgboost
#   -> predict function  : <function predict_function at 0x7fe0ced143b0> will be used
#   -> predict function  : accepts only pandas.DataFrame, numpy.ndarray causes problems
#   -> predicted values  : min = 1.28e+05, mean = 5.31e+05, max = 5.49e+06
#   -> model type        : regression will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -1.01e+06, mean = 1.11e+04, max = 2.31e+06
#   -> model_info        : package xgboost
#
# A new explainer has been created!

# %%
show_methods(exp)
# Out:
#        0                  1                  2                  3
# 0   data        model_class    model_surrogate           residual
# 1   dump  model_diagnostics         model_type  residual_function
# 2  dumps     model_fairness            predict          residuals
# 3  label         model_info   predict_function            weights
# 4   load        model_parts      predict_parts                  y
# 5  loads  model_performance    predict_profile              y_hat
# 6  model      model_profile  predict_surrogate

# %% [markdown]
# ## [DATASET LEVEL](https://pbiecek.github.io/ema/dataset-level.html)

# %% [markdown]
# ### [Model Performance](https://pbiecek.github.io/ema/modelPerformance.html)

# %%
mp = exp.model_performance('regression')
mp.result
# Out:
#                   mse           rmse        r2           mae          mad
# xgboost  1.220401e+10  110471.757834  0.909445  62077.413965  36802.65625

# %%
type(mp)
# Out:
# dalex.dataset_level._model_performance.object.ModelPerformance

# %%
show_methods(mp,6)
# Out:
#         0    1           2     3          4       5
# 0  cutoff  fit  model_type  plot  residuals  result

# %%
mp.plot() # if we have 2 models, we can use mp.plot(mp2)
# Out:
# <div>                            <div id="857f1b1d-79d7-43af-8508-43542b199737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
625, 2932.1875, 2938.796875, 2981.34375, 2986.6875, 3018.4375, 3019.59375, 3033.53125, 3033.59375, 3042.25, 3052.6875, 3080.875, 3081.0625, 3085.375, 3091.1875, 3116.1875, 3137.53125, 3137.65625, 3170.84375, 3186.375, 3188.28125, 3197.0625, 3201.375, 3214.21875, 3243.625, 3250.0625, 3269.5625, 3281.0, 3282.375, 3286.28125, 3311.8125, 3367.5625, 3372.15625, 3382.4375, 3384.0625, 3422.6875, 3436.8125, 3437.5, 3439.3125, 3455.046875, 3462.9375, 3477.625, 3492.203125, 3499.5625, 3511.4375, 3512.5625, 3514.40625, 3516.9375, 3530.8125, 3570.9375, 3584.0, 3591.0625, 3630.3125, 3631.5625, 3641.1875, 3647.90625, 3657.3125, 3668.21875, 3673.0, 3682.375, 3699.65625, 3724.21875, 3750.71875, 3757.34375, 3791.296875, 3805.4375, 3806.78125, 3822.1875, 3824.625, 3839.875, 3844.09375, 3858.1875, 3860.734375, 3868.90625, 3916.90625, 3937.46875, 3943.09375, 3965.21875, 3968.71875, 3975.25, 4013.90625, 4013.9375, 4038.5, 4047.8125, 4048.1875, 4058.046875, 4063.75, 4074.75, 4102.3125, 4152.28125, 4157.90625, 4187.34375, 4204.21875, 4204.375, 4208.1875, 4209.125, 4244.203125, 4248.59375, 4250.34375, 4252.75, 4257.09375, 4259.8125, 4307.25, 4322.4375, 4324.34375, 4326.34375, 4328.90625, 4347.8125, 4354.4375, 43 ...

# %% [markdown]
# ###  [Variable Importance using: model_parts](https://pbiecek.github.io/ema/featureImportance.html)
#
# Customize the computation with parameters:
#
# - **loss_function** function to use for drop-out loss evaluation
#
# - **B** number of bootstrap rounds (e.g. `15` for slower computation but more stable results)
#
# - **N** number of observations to use (e.g. `500` for faster computation but less stable results)
#
# - **variable_groups** Dict of lists of variables. Each list is treated as one group. This is for testing joint variable importance

# %%
df_Xtest.columns.to_numpy()
# Out:
# array(['age', 'age_after_renovation', 'age_after_renovation_cat',
#        'age_after_renovation_sq', 'age_cat', 'age_sq', 'basement_bool',
#        'bathrooms', 'bathrooms_sq', 'bedrooms', 'bedrooms_sq',
#        'condition', 'condition_1', 'condition_2', 'condition_3',
#        'condition_4', 'condition_5', 'floors', 'floors_sq', 'grade',
#        'grade_10', 'grade_11', 'grade_12', 'grade_13', 'grade_4',
#        'grade_5', 'grade_6', 'grade_7', 'grade_8', 'grade_9', 'lat',
#        'log1p_sqft_above', 'log1p_sqft_above_sq', 'log1p_sqft_basement',
#        'log1p_sqft_basement_sq', 'log1p_sqft_living',
#        'log1p_sqft_living15', 'log1p_sqft_living15_sq',
#        'log1p_sqft_living_sq', 'log1p_sqft_lot', 'log1p_sqft_lot15',
#        'log1p_sqft_lot15_sq', 'log1p_sqft_lot_sq', 'long',
#        'renovation_bool', 'sqft_above', 'sqft_basement', 'sqft_living',
#        'sqft_living15', 'sqft_lot', 'sqft_lot15', 'view', 'view_0',
#        'view_1', 'view_2', 'view_3', 'view_4', 'view_sq', 'waterfront',
#        'waterfront_0', 'waterfront_1', 'waterfront_sq', 'yr_built',
#        'yr_renovated', 'yr_renovated2', 'yr_sales', 'zipcode'],
#       dtype=object)

# %%
variable_groups = {
    'age': ['age', 'age_after_renovation',
            'age_after_renovation_cat',
            'age_after_renovation_sq', 'age_cat', 'age_sq'],

    'bathrooms': ['bathrooms', 'bathrooms_sq'],

    'bedrooms': ['bedrooms', 'bedrooms_sq'],

    'condition': ['condition', 'condition_1',
                  'condition_2', 'condition_3',
                  'condition_4', 'condition_5'],

    'floor': ['floors', 'floors_sq'],

    'grade': ['grade','grade_10', 'grade_11',
              'grade_12', 'grade_13', 'grade_4',
              'grade_5', 'grade_6', 'grade_7',
              'grade_8', 'grade_9'],

    'lat_long': ['lat','long'],

    'sqft' : ['sqft_above', 'sqft_basement', 'sqft_living',
        'sqft_living15', 'sqft_lot', 'sqft_lot15',
        'log1p_sqft_above', 'log1p_sqft_above_sq',
        'log1p_sqft_basement','log1p_sqft_basement_sq',
        'log1p_sqft_living','log1p_sqft_living15',
        'log1p_sqft_living15_sq','log1p_sqft_living_sq',
        'log1p_sqft_lot', 'log1p_sqft_lot15',
        'log1p_sqft_lot15_sq', 'log1p_sqft_lot_sq'],
    
    'bool': ['renovation_bool'],

    'view': ['view', 'view_0','view_1', 'view_2', 'view_3',
             'view_4', 'view_sq'],

    'waterfront': ['waterfront','waterfront_0',
                   'waterfront_1', 'waterfront_sq'],

    'year': ['yr_built','yr_renovated',
             'yr_renovated2', 'yr_sales'],

    'zipcode': ['zipcode']

}

# %% [markdown]
# ```python
# model_parts(
#     loss_function=None,
#     type=('variable_importance', 'ratio', 'difference', 'shap_wrapper'),
#     N=1000,
#     B=10, # num perm rounds, default = 10
#     variables=None, # select only those variables
#     variable_groups=None,
#     keep_raw_permutations=True,
#     processes=1,
#     random_state=None,
#     **kwargs)
# ```
#
# Customize the plot with parameters:
#
#
# ```python
# plot(objects=None,
#      max_vars=10,
#      digits=3,
#      rounding_function=<function around at 0x7fe0ced94560>,
#      bar_width=16,
#      split=('model', 'variable'),
#      title='Variable Importance',
#      vertical_spacing=None,
#      show=True)
# ```
#
# - **vertical_spacing** value between 0.0 and 1.0 (e.g. 0.15 for more space between the plots)
#
# - **rounding_function** rounds the contributions (e.g. `np.round`, `np.rint`, `np.ceil`)
#
# - **digits** (e.g. 2 for `np.round`, `None` for `np.rint`)

# %%
mparts = exp.model_parts(variable_groups=variable_groups,B=15)

# %%
mparts.plot(max_vars=10,rounding_function=np.rint,
        digits=None,vertical_spacing=0.15)
# Out:
# <div>                            <div id="5d137848-1a0f-445d-8ad4-37872fe66315" class="plotly-graph-div" style="height:383.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d137848-1a0f-445d-8ad4-37872fe66315")) {                    Plotly.newPlot(                        "5d137848-1a0f-445d-8ad4-37872fe66315",                        [{"base": 115503.26667490813, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Model: xgboost loss after<br>variable: lat_long is permuted: 300433.0<br>Drop-out loss change: +184929.0", "Model: xgboost loss after<br>variable: sqft is permuted: 298900.0<br>Drop-out loss change: +183397.0", "Model: xgboost loss after<br>variable: grade is permuted: 191116.0<br>Drop-out loss change: +75613.0", "Model: xgboost loss after<br>variable: waterfront is permuted: 147820.0<br>Drop-out loss change: +32317.0", "Model: xgboost loss after<br>variable: zipcode is permuted: 141755.0<br>Drop-out loss change: +26251.0", "Model: xgboost loss after<br>variable: view is permuted: 134220.0<br>Drop-out loss change: +18717.0", "Model: xgboost loss after<br>variable: year is permuted: 132162.0<br>Drop-out loss change: +16659.0", "Model: xgboost loss after<br>variable: bathrooms is permuted: 128746.0<br>Drop-out loss change: +13242.0", "Model: xgboost loss after<br>variable: age is permuted: 124621.0<br>Drop-out loss change: +9118.0", "Model: xgboost loss after<br>variable: condition is permuted: 119900.0<br>Drop-out loss change: +4396.0"], "marker": {"color": "#46bac2"}, "orientation": "h", "showlegend": false, "text": ["+184929.0", "+183397.0", "+75613.0", "+32317.0", "+26251.0", "+18717.0", "+16659.0", "+13242.0", "+9118.0", "+4396.0"], "textposition": "outside", "type": "bar", "x": [184929.3897841869, 183397.11582156643, 75612.98789535793, 32316.86505426535, 26251.34883236514, 18716.74207757252, 16659.142703476668, 13242.496224433067, 9118.213209853275, 4396.284746212739], "xaxis": "x", "y": ["lat_long", "sqft", "grade", "waterfront", "zipcode", "view", "year", "bathrooms", "age", "condition"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "xgboost", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "drop-out loss", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 383.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 115503.26667490813, "x1": 115503.26667490813, "xref": "x", "y0": -1, "y1": 10, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Variable Importance", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [85475.07254980427, 328470.6021863938], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('5d137848-1a0f-445d-8ad4-37872fe66315');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ### model_profile: accumulated
#
# ```python
# model_profile(type=('partial', 'accumulated', 'conditional'),
#               N=300, # num of obs to use **most imp param **
#               variables=None,
#               variable_type='numerical',
#               groups=None,
#               span=0.25,
#               grid_points=101,
#               variable_splits=None,
#               variable_splits_type='uniform',
#               center=True,
#               processes=1,
#               random_state=None,
#               verbose=True)
# ```
#
# Choose a proper algorithm. The explanations can be calulated as [Partial Dependence Profile](https://pbiecek.github.io/ema/partialDependenceProfiles.html) or [Accumulated Local Dependence Profile](https://pbiecek.github.io/ema/accumulatedLocalProfiles.html).
#
# The key parameter is **N** number of observations to use (e.g. `800` for slower computation but more stable results).

# %%
# help(exp.model_profile)

# %%
# %%time

path_mprof_accm = '../models/dalex_mprof_accm.joblib'

if not os.path.exists(path_mprof_accm):
    mprof_accm = exp.model_profile(type='accumulated',N=800)
    mprof_accm.result['_label_'] = 'accumulated'
    joblib.dump(mprof_accm, path_mprof_accm)
# Out:
# Calculating ceteris paribus: 100%|██████████| 67/67 [01:09<00:00,  1.03s/it]
# /Users/poudel/opt/miniconda3/envs/ray/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#
# Calculating accumulated dependency: 100%|██████████| 67/67 [00:15<00:00,  4.22it/s]

# %%
variables = ['age',
             'bathrooms', 'bedrooms',
#     'condition',  'floors', 'grade',
    'lat','long',
#     'sqft_above', 'sqft_basement', 'sqft_living',
#     'view',  'waterfront', 'zipcode'
            ]

mprof_accm = joblib.load(path_mprof_accm)
mprof_accm.plot(variables=variables) # use first parameter another model, if you have it.
# Out:
# <div>                            <div id="51978af3-d79f-49ae-a430-a718dae86af2" class="plotly-graph-div" style="height:1169px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# %% [markdown]
# ### Model Profile: Partial (pdp)

# %%
# %%time
path_mprof_pdp = '../models/dalex_mprof_pdp.joblib'

if not os.path.exists(path_mprof_pdp):
    mprof_pdp = exp.model_profile(type='partial',N=800)
    mprof_pdp.result['_label_'] = 'pdp'
    joblib.dump(mprof_pdp, path_mprof_pdp)
# Out:
# CPU times: user 2.29 s, sys: 4.18 s, total: 6.47 s
# Wall time: 10.5 s
# ['../models/dalex_mprof_pdp.joblib']

# %%
mprof_pdp = joblib.load(path_mprof_pdp)
mprof_pdp.plot(mprof_accm, variables=variables)
# Out:
# <div>                            <div id="a00daceb-4040-489c-92f7-2c55b0b74920" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a00daceb-4040-489c-92f7-2c55b0b74920")) {                    Plotly.newPlot(                        "a00daceb-4040-489c-92f7-2c55b0b74920",                        [{"customdata": [[300313.21875, 527633.1875, "pdp", "lat", -2.9177118374236284], [300313.21875, 527633.1875, "pdp", "lat", -2.8728509475350656], [300313.21875, 527633.1875, "pdp", "lat", -2.8279900576465025], [300313.21875, 527633.1875, "pdp", "lat", -2.7831291677579397], [300317.6875, 527633.1875, "pdp", "lat", -2.738268277869377], [300317.6875, 527633.1875, "pdp", "lat", -2.693407387980814], [300317.6875, 527633.1875, "pdp", "lat", -2.648546498092251], [300361.25, 527633.1875, "pdp", "lat", -2.603685608203688], [300361.25, 527633.1875, "pdp", "lat", -2.558824718315125], [299907.71875, 527633.1875, "pdp", "lat", -2.5139638284265624], [299907.71875, 527633.1875, "pdp", "lat", -2.4691029385379992], [302144.53125, 527633.1875, "pdp", "lat", -2.4242420486494365], [302144.53125, 527633.1875, "pdp", "lat", -2.3793811587608737], [302144.53125, 527633.1875, "pdp", "lat", -2.3345202688723106], [302144.53125, 527633.1875, "pdp", "lat", -2.289659378983748], [302144.53125, 527633.1875, "pdp", "lat", -2.244798489095185], [300554.25, 527633.1875, "pdp", "lat", -2.199937599206622], [303863.625, 527633.1875, "pdp", "lat", -2.155076709318059], [306267.8125, 527633.1875, "pdp", "lat", -2.110215819429496], [309254.875, 527633.1875, "pdp", "lat", -2.0653549295409332], [310966.875, 527633.1875, "pdp", "lat", -2.0204940396523705], [310966.875, 527633.1875, "pdp", "lat", -1.9756331497638076], [310841.96875, 527633.1875, "pdp", "lat", -1.9307722598752446], [312181.78125, 527633.1875, "pdp", "lat", -1.8859113699866816], [313157.1875, 527633.1875, "pdp", "lat", -1.841050480098119], [313157.1875, 527633.1875, "pdp", "lat", -1.796189590209556], [313238.71875, 527633.1875, "pdp", "lat", -1.751328700320993], [323135.9375, 527633.1875, "pdp", "lat", -1.7064678104324302], [326259.78125, 527633.1875, "pdp", "lat", -1.6616069205438673], [329786.0, 527633.1875, "pdp", "lat", -1.6167460306553043], [335240.90625, 527633.1875, "pdp", "lat", -1.5718851407667414], [331940.5, 527633.1875, "pdp", "lat", -1.5270242508781786], [338785.53125, 527633.1875, "pdp", "lat", -1.4821633609896157], [338387.59375, 527633.1875, "pdp", "lat", -1.4373024711010527], [338511.59375, 527633.1875, "pdp", "lat", -1.39244158121249], [339067.71875, 527633.1875, "pdp", "lat", -1.347580691323927], [337345.8125, 527633.1875, "pdp", "lat", -1.302719801435364], [338138.125, 527633.1875, "pdp", "lat", -1.257858911546801], [343804.71875, 527633.1875, "pdp", "lat", -1.2129980216582383], [349476.1875, 527633.1875, "pdp", "lat", -1.1681371317696754], [353446.6875, 527633.1875, "pdp", "lat", -1.1232762418811124], [360705.84375, 527633.1875, "pdp", "lat", -1.0784153519925497], [367198.46875, 527633.1875, "pdp", "lat", -1.0335544621039867], [367417.84375, 527633.1875, "pdp", "lat", -0.9886935722154238], [375688.625, 527633.1875, "pdp", "lat", -0.9438326823268608], [381297.84375, 527633.1875, "pdp", "lat", -0.8989717924382981], [380240.5625, 527633.1875, "pdp", "lat", -0.8541109025497349], [377136.96875, 527633.1875, "pdp", "lat", -0.8092500126611721], [382778.71875, 527633.1875, "pdp", "lat", -0.7643891227726094], [384869.25, 527633.1875, "pdp", "lat", -0.7195282328840462], [389853.625, 527633.1875, "pdp", "lat", -0.6746673429954835], [393250.40625, 527633.1875, "pdp", "lat", -0.6298064531069207], [404157.03125, 527633.1875, "pdp", "lat", -0.5849455632183576], [403643.0, 527633.1875, "pdp", "lat", -0.5400846733297948], [405160.625, 527633.1875, "pdp", "lat", -0.4952237834412321], [4 ...

# %% [markdown]
# ### Model Profile: partial with categorical

# %%
df_Xtest.head(2)
# Out:
#         age  age_after_renovation  age_after_renovation_cat  \
# 0 -1.372335             -1.316486                 -1.265291
# 1 -0.084817             -0.005269                 -0.062185
#
#    age_after_renovation_sq   age_cat    age_sq  basement_bool  bathrooms  \
# 0                -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 1                -0.285363 -0.139825 -0.348085      -0.801818   0.506258
#
#    bathrooms_sq  bedrooms  ...   view_sq  waterfront  waterfront_0  \
# 0      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
# 1      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
#
#    waterfront_1  waterfront_sq  yr_built  yr_renovated  yr_renovated2  \
# 0     -0.089698      -0.089698  1.361464     -0.207992       1.305630
# 1     -0.089698      -0.089698  0.107715     -0.207992       0.028586
#
#    yr_sales   zipcode
# 0 -0.693043 -1.422563
# 1  1.442912 -1.441324
#
# [2 rows x 67 columns]

# %%
variables = ["grade","waterfront"]
df_Xtest[variables].apply(pd.Series.nunique)
# Out:
# grade         10
# waterfront     2
# dtype: int64

# %%
# %%time

path_mprof_accm_cat = '../models/dalex_mprof_accm_cat.joblib'
path_mprof_pdp_cat = '../models/dalex_mprof_pdp_cat.joblib'

if not os.path.exists(path_mprof_accm_cat):
    mprof_accm_cat = exp.model_profile(type = 'accumulated',
                                       variable_type='categorical',
                                       variables=variables)
    mprof_accm_cat.result.loc[:, '_label_'] = 'accumulated_cat'
    joblib.dump(mprof_accm_cat, path_mprof_accm_cat)

if not os.path.exists(path_mprof_pdp_cat):
    mprof_pdp_cat = exp.model_profile(type = 'partial',
                                      variable_type='categorical',
                                      variables=variables)
    mprof_pdp_cat.result.loc[:, '_label_'] = 'pdp_cat'
    joblib.dump(mprof_pdp_cat, path_mprof_pdp_cat)
# Out:
# Calculating ceteris paribus: 100%|██████████| 2/2 [00:00<00:00,  2.34it/s]
# /Users/poudel/opt/miniconda3/envs/ray/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#
# Calculating accumulated dependency: 100%|██████████| 2/2 [00:00<00:00, 12.67it/s]
# Calculating ceteris paribus: 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]
# CPU times: user 8.18 s, sys: 365 ms, total: 8.54 s
# Wall time: 3.81 s

# %%
mprof_accm_cat = joblib.load(path_mprof_accm_cat)
mprof_pdp_cat = joblib.load(path_mprof_pdp_cat)

# %%
mprof_accm_cat.plot(mprof_pdp_cat)
# Out:
# <div>                            <div id="2a7b7117-81ec-4620-8666-1c3f158f5143" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a7b7117-81ec-4620-8666-1c3f158f5143")) {                    Plotly.newPlot(                        "2a7b7117-81ec-4620-8666-1c3f158f5143",                        [{"alignmentgroup": "True", "base": [532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0, 532422.0], "customdata": [[532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-3.0969640695973464"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-3.020701476409911"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.944438883222475"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.8681762900350396"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.791913696847604"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.7156511036601683"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.639388510472733"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.563125917285297"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.4868633240978615"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.410600730910426"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.33433813772299"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.2580755445355547"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.1818129513481193"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.1055503581606834"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-2.029287764973248"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.9530251717858125"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.8767625785983768"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.8004999854109411"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.7242373922235057"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.64797479903607"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.5717122058486344"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.495449612661199"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.4191870194737632"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.3429244262863276"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.2666618330988921"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.1903992399114565"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.1141366467240208"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-1.0378740535365854"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-0.9616114603491495"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-0.885348867161714"], [532422.0, 532422.0, 0.0, "accumulated_cat", "grade", "-0.8090862739742786"], [5 ...

# %% [markdown]
# ## [INSTANCE LEVEL](https://pbiecek.github.io/ema/InstanceLevelExploration.html)

# %% [markdown]
# ### Predict

# %%
john = df_Xtest.iloc[[0]] # we need df not series, so use [[index]]
john.index.name = 'John'
mary = df_Xtest.iloc[[1]]
mary.index.name = 'Mary'
print(type(john))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
exp.predict(john)
# Out:
# array([343218.4], dtype=float32)

# %% [markdown]
# ### Variable Attribution (predict_parts)

# %% [markdown]
# ```python
# predict_parts(new_observation,
#     type=('break_down_interactions', 'break_down', 'shap', 'shap_wrapper'),
#     order=None,
#     interaction_preference=1,
#     path='average',
#     B=25,
#     keep_distributions=False,
#     processes=1,
#     random_state=None,
#     **kwargs)
# ```
#
# Here we can choose our varible attribution types. The explanations can be calulated as [Break Down](https://pbiecek.github.io/ema/breakDown.html), [iBreakDown](https://pbiecek.github.io/ema/iBreakDown.html) or [Shapley Values](https://pbiecek.github.io/ema/shapley.html).
#
# For `type='shap'` the key parameter is **B** number of bootstrap rounds (e.g. `10` for faster computation but less stable results).
#
# Let's find out what attributes to the house price.

# %%
# help(exp.predict_parts)

# %%
df_Xtest.head(2)
# Out:
#         age  age_after_renovation  age_after_renovation_cat  \
# 0 -1.372335             -1.316486                 -1.265291
# 1 -0.084817             -0.005269                 -0.062185
#
#    age_after_renovation_sq   age_cat    age_sq  basement_bool  bathrooms  \
# 0                -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 1                -0.285363 -0.139825 -0.348085      -0.801818   0.506258
#
#    bathrooms_sq  bedrooms  ...   view_sq  waterfront  waterfront_0  \
# 0      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
# 1      0.326221  -0.39033  ... -0.261712   -0.089698      0.089698
#
#    waterfront_1  waterfront_sq  yr_built  yr_renovated  yr_renovated2  \
# 0     -0.089698      -0.089698  1.361464     -0.207992       1.305630
# 1     -0.089698      -0.089698  0.107715     -0.207992       0.028586
#
#    yr_sales   zipcode
# 0 -0.693043 -1.422563
# 1  1.442912 -1.441324
#
# [2 rows x 67 columns]

# %%
# %%time
john_bd  = exp.predict_parts(john, type='break_down')
john_bdi = exp.predict_parts(john, type='break_down_interactions')
john_sh  = exp.predict_parts(john, type='shap', B = 10)

mary_bd  = exp.predict_parts(mary, type='break_down')
mary_bdi = exp.predict_parts(mary, type='break_down_interactions')
mary_sh  = exp.predict_parts(mary, type='shap', B = 10)
# Out:
# CPU times: user 19min 52s, sys: 5.74 s, total: 19min 58s
# Wall time: 5min 54s

# %%
john_bd.result.label = "John_bd"
john_bdi.result.label = "John_bdi"
john_sh.result.label = "John_sh"

mary_bd.result.label = "John_bd"
mary_bdi.result.label = "John_bdi"
mary_sh.result.label = "John_sh"

john_bd.result.head()
# Out:
#        variable_name variable_value                    variable   cumulative  \
# 0          intercept              1                   intercept  531207.3750
# 1            zipcode         -1.423            zipcode = -1.423  616282.0625
# 2               long        0.02592              long = 0.02592  665207.8750
# 3      yr_renovated2          1.306       yr_renovated2 = 1.306  697822.0000
# 4  log1p_sqft_living         0.5907  log1p_sqft_living = 0.5907  731214.5625
#
#    contribution  sign  position    label
# 0   531207.3750   1.0        68  John_bd
# 1    85074.6875   1.0        67  John_bd
# 2    48925.8125   1.0        66  John_bd
# 3    32614.1250   1.0        65  John_bd
# 4    33392.5625   1.0        64  John_bd

# %%
john_bd.plot(john_bdi)
# Out:
# <div>                            <div id="2c55744f-e0d0-493a-9db8-fa35b340e2ca" class="plotly-graph-div" style="height:747.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c55744f-e0d0-493a-9db8-fa35b340e2ca")) {                    Plotly.newPlot(                        "2c55744f-e0d0-493a-9db8-fa35b340e2ca",                        [{"base": 531207.375, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.4<br>Prediction: 343218.4", "zipcode = -1.423<br>increases average response by", "long = 0.02592<br>increases average response by", "yr_renovated2 = 1.306<br>increases average response by", "log1p_sqft_living = 0.5907<br>increases average response by", "age_after_renovation = -1.316<br>increases average response by", "log1p_sqft_basement = -0.7955<br>increases average response by", "yr_built = 1.361<br>increases average response by", "log1p_sqft_living15 = 0.7911<br>increases average response by", "log1p_sqft_above = 0.9489<br>increases average response by", "grade_7 = 1.187<br>increases average response by", "+ all other factors<br>decreases average response by", "Average response: 531207.4<br>Prediction: 343218.4"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["531207.4", "+85074.69", "+48925.812", "+32614.123", "+33392.562", "+22935.877", "+15534.188", "+9365.375", "+8678.312", "+23943.0", "+5300.188", "-138880.38", "343218.4"], "textposition": "outside", "totals": {"marker": {"color": "#371ea3"}}, "type": "waterfall", "x": [0.0, 85074.6875, 48925.8125, 32614.123046875, 33392.5625, 22935.876953125, 15534.1884765625, 9365.375, 8678.3115234375, 23943.0, 5300.18798828125, -138880.375, -187988.96875], "xaxis": "x", "y": ["intercept", "zipcode = -1.423", "long = 0.02592", "yr_renovated2 = 1.306", "log1p_sqft_living = 0.5907", "age_after_renovation = -1.316", "log1p_sqft_basement = -0.7955", "yr_built = 1.361", "log1p_sqft_living15 = 0.7911", "log1p_sqft_above = 0.9489", "grade_7 = 1.187", "+ all other factors", "prediction"], "yaxis": "y"}, {"base": 531207.375, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.4<br>Prediction: 343218.4", "lat = -1.505<br>decreases average response by", "zipcode = -1.423<br>increases average response by", "grade = -0.5549<br>decreases average response by", "long = 0.02592<br>decreases average response by", "yr_renovated2 = 1.306<br>increases average response by", "log1p_sqft_living = 0.5907<br>increases average response by", "log1p_sqft_lot = -0.4895<br>decreases average response by", "age_after_renovation = -1.316<br>increases average response by", "condition = -0.6306<br>decreases average response by", "view = -0.3055<br>decreases average response by", "+ all other factors<br>increases average response by", "Average response: 531207.4<br>Prediction: 343218.4"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["531207.4", "-192443.69", "+5474.438", "-31703.031", "-7708.438", "+10112.281", "+22696.562", "-20799.344", "+14953.375", "-1574.906", "-5758.688", "+18762.5", "343218. ...
#
# var gd = document.getElementById('2c55744f-e0d0-493a-9db8-fa35b340e2ca');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
john_sh.plot(max_vars=5)
# Out:
# <div>                            <div id="9f37a971-f40c-48f4-b39a-319dea821326" class="plotly-graph-div" style="height:273.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f37a971-f40c-48f4-b39a-319dea821326")) {                    Plotly.newPlot(                        "9f37a971-f40c-48f4-b39a-319dea821326",                        [{"base": 531207.375, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.4<br>Prediction: 343218.4<br>lat = -1.505<br>decreases average response <br>by 262387.294", "Average response: 531207.4<br>Prediction: 343218.4<br>zipcode = -1.423<br>increases average response <br>by 48648.7", "Average response: 531207.4<br>Prediction: 343218.4<br>grade = -0.5549<br>decreases average response <br>by 37675.538", "Average response: 531207.4<br>Prediction: 343218.4<br>log1p_sqft_living = 0.5907<br>increases average response <br>by 30113.925", "Average response: 531207.4<br>Prediction: 343218.4<br>+ all other factors<br>increases average response <br>by 33311.269"], "marker": {"color": ["#f05a71", "#8bdcbe", "#f05a71", "#8bdcbe", "#8bdcbe"]}, "orientation": "h", "showlegend": false, "text": ["-262387.294", "+48648.7", "-37675.538", "+30113.925", "+33311.269"], "textposition": "outside", "type": "bar", "x": [-262387.294, 48648.7, -37675.538, 30113.925, 33311.269], "xaxis": "x", "y": ["lat = -1.505", "zipcode = -1.423", "grade = -0.5549", "log1p_sqft_living = 0.5907", "+ all other factors"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "John_sh", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 273.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 531207.375, "x1": 531207.375, "xref": "x", "y0": -1, "y1": 6, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Shapley Values", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [222164.68190000003, 626511.4741], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('9f37a971-f40c-48f4-b39a-319dea821326');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
mary_sh.plot(max_vars=5)
# Out:
# <div>                            <div id="1b0d1679-7076-401d-96af-5b10cd0e7815" class="plotly-graph-div" style="height:273.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b0d1679-7076-401d-96af-5b10cd0e7815")) {                    Plotly.newPlot(                        "1b0d1679-7076-401d-96af-5b10cd0e7815",                        [{"base": 531207.375, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.4<br>Prediction: 204292.34<br>lat = -2.128<br>decreases average response <br>by 255134.05", "Average response: 531207.4<br>Prediction: 204292.34<br>zipcode = -1.441<br>increases average response <br>by 39317.795", "Average response: 531207.4<br>Prediction: 204292.34<br>log1p_sqft_living = -0.4603<br>decreases average response <br>by 35622.031", "Average response: 531207.4<br>Prediction: 204292.34<br>grade = -0.5549<br>decreases average response <br>by 28408.348", "Average response: 531207.4<br>Prediction: 204292.34<br>+ all other factors<br>decreases average response <br>by 47068.381"], "marker": {"color": ["#f05a71", "#8bdcbe", "#f05a71", "#f05a71", "#f05a71"]}, "orientation": "h", "showlegend": false, "text": ["-255134.05", "+39317.795", "-35622.031", "-28408.348", "-47068.381"], "textposition": "outside", "type": "bar", "x": [-255134.05, 39317.795, -35622.031, -28408.348, -47068.381], "xaxis": "x", "y": ["lat = -2.128", "zipcode = -1.441", "log1p_sqft_living = -0.4603", "grade = -0.5549", "+ all other factors"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "John_sh", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 273.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 531207.375, "x1": 531207.375, "xref": "x", "y0": -1, "y1": 6, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Shapley Values", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [231905.54825, 614692.94675], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('1b0d1679-7076-401d-96af-5b10cd0e7815');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# %%time

# Please persist the result and comment this cell
#
#
# # variable attribution
# va = {'ibd':[], 'sh':[]} # instance breakdown and shapely

# for idx in df_Xtest.index[0:3]:
#     rowname = df_Xtest.loc[name,]
#     # if we have index name, then this is useful

#     ibd = exp.predict_parts(rowname, type='break_down_interactions')
#     ibd.result.label = str(rowname)

#     sh = exp.predict_parts(rowname, type='shap', B=1)
#     sh.result.label = str(rowname)

#     va['ibd'].append(ibd)
#     va['sh'].append(sh)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs

# %%
# the variable attribution takes long time, persist the file
path_va = '../models/dalex_variable_attributes.joblib'
joblib.dump(va, path_va)

va = joblib.load(path_va)

# %%
va['ibd'][0].plot(va['ibd'][1:3],
                  rounding_function=np.rint,
                  digits=None, max_vars=10)
# Out:
# <div>                            <div id="bf68e2ed-3ae4-4985-bb5e-57a318c724e4" class="plotly-graph-div" style="height:1081.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf68e2ed-3ae4-4985-bb5e-57a318c724e4")) {                    Plotly.newPlot(                        "bf68e2ed-3ae4-4985-bb5e-57a318c724e4",                        [{"base": 531207.375, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.0<br>Prediction: 508421.0", "lat = -0.7829<br>decreases average response by", "log1p_sqft_lot = 1.968<br>increases average response by", "grade = 1.14<br>increases average response by", "long = 0.9176<br>decreases average response by", "log1p_sqft_living15 = -0.2739<br>decreases average response by", "log1p_sqft_living = 0.5448<br>increases average response by", "yr_renovated2 = 1.168<br>increases average response by", "condition = -0.6306<br>decreases average response by", "view = -0.3055<br>decreases average response by", "yr_sales = -0.693<br>decreases average response by", "+ all other factors<br>increases average response by", "Average response: 531207.0<br>Prediction: 508421.0"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["531207.0", "-148642.0", "+63474.0", "+49956.0", "-10833.0", "-13322.0", "+29076.0", "+23495.0", "-11942.0", "-7988.0", "-5694.0", "+9634.0", "508421.0"], "textposition": "outside", "totals": {"marker": {"color": "#371ea3"}}, "type": "waterfall", "x": [0.0, -148642.0, 63474.0, 49956.0, -10833.0, -13322.0, 29076.0, 23495.0, -11942.0, -7988.0, -5694.0, 9634.0, -22787.0], "xaxis": "x", "y": ["intercept", "lat = -0.7829", "log1p_sqft_lot = 1.968", "grade = 1.14", "long = 0.9176", "log1p_sqft_living15 = -0.2739", "log1p_sqft_living = 0.5448", "yr_renovated2 = 1.168", "condition = -0.6306", "view = -0.3055", "yr_sales = -0.693", "+ all other factors", "prediction"], "yaxis": "y"}, {"base": 531207.375, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 531207.0<br>Prediction: 508421.0", "lat = -0.7829<br>decreases average response by", "log1p_sqft_lot = 1.968<br>increases average response by", "grade = 1.14<br>increases average response by", "long = 0.9176<br>decreases average response by", "log1p_sqft_living15 = -0.2739<br>decreases average response by", "log1p_sqft_living = 0.5448<br>increases average response by", "yr_renovated2 = 1.168<br>increases average response by", "condition = -0.6306<br>decreases average response by", "view = -0.3055<br>decreases average response by", "yr_sales = -0.693<br>decreases average response by", "+ all other factors<br>increases average response by", "Average response: 531207.0<br>Prediction: 508421.0"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["531207.0", "-148642.0", "+63474.0", "+49956.0", "-10833.0", "-13322.0", "+29076.0", "+23495.0", "-11942.0", "-7988.0", "-5694.0", "+9634.0", "508421.0"], "textposition": "outside", "totals": {"marker": {"color": "#371ea3"}}, "type": "waterfall", "x": [0.0, -148642.0, 63474.0, 49956.0, -10833.0, -13322.0, 29076 ...

# %%
va['sh'][0].plot(va['sh'][1:3], 
                 rounding_function=np.rint, 
                 digits=None, max_vars=10)
# Out:
# <div>                            <div id="17e319c3-5e34-4af9-b335-fd8e78b8a258" class="plotly-graph-div" style="height:961.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17e319c3-5e34-4af9-b335-fd8e78b8a258")) {                    Plotly.newPlot(                        "17e319c3-5e34-4af9-b335-fd8e78b8a258",                        [{"base": 531207.375, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response:
#
# Looking at the Break Down plots, age and movement_ractions variables are standing out. Let's focus on them more.

# %%
# %%time

john_cp = exp.predict_profile(john)
mary_cp = exp.predict_profile(mary)

john_cp.result.head()
# Out:
# Calculating ceteris paribus: 100%|██████████| 67/67 [00:00<00:00, 116.60it/s]
# Calculating ceteris paribus: 100%|██████████| 67/67 [00:00<00:00, 133.28it/s]
# CPU times: user 4.13 s, sys: 77.2 ms, total: 4.21 s
# Wall time: 1.32 s
#            age  age_after_renovation  age_after_renovation_cat  \
# John
# 0    -1.507863             -1.316486                 -1.265291
# 0    -1.468560             -1.316486                 -1.265291
# 0    -1.429257             -1.316486                 -1.265291
# 0    -1.389954             -1.316486                 -1.265291
# 0    -1.372335             -1.316486                 -1.265291
#
#       age_after_renovation_sq   age_cat    age_sq  basement_bool  bathrooms  \
# John
# 0                   -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 0                   -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 0                   -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 0                   -0.845091 -1.320662 -0.885667      -0.801818   0.506258
# 0                   -0.845091 -1.320662 -0.885667      -0.801818   0.506258
#
#       bathrooms_sq  bedrooms  ...  yr_built  yr_renovated  yr_renovated2  \
# John                          ...
# 0         0.326221  -0.39033  ...  1.361464     -0.207992        1.30563
# 0         0.326221  -0.39033  ...  1.361464     -0.207992        1.30563
# 0         0.326221  -0.39033  ...  1.361464     -0.207992        1.30563
# 0         0.326221  -0.39033  ...  1.361464     -0.207992        1.30563
# 0         0.326221  -0.39033  ...  1.361464     -0.207992        1.30563
#
#       yr_sales   zipcode  _original_        _yhat_  _vname_  _ids_  _label_
# John
# 0    -0.693043 -1.422563   -1.372335  343218.40625      age      0  xgboost
# 0    -0.693043 -1.422563   -1.372335  343218.40625      age      0  xgboost
# 0    -0.693043 -1.422563   -1.372335  343218.40625      age      0  xgboost
# 0    -0.693043 -1.422563   -1.372335  343218.40625      age      0  xgboost
# 0    -0.693043 -1.422563   -1.372335  343218.40625      age      0  xgboost
#
# [5 rows x 72 columns]

# %%
# john_cp.plot(mary_cp, variable_type='categorical')

john_cp.plot(mary_cp, variables=['age','grade'])
# Out:
# <div>                            <div id="3eed2219-dfb6-4715-8364-2c6cf97de3e7" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eed2219-dfb6-4715-8364-2c6cf97de3e7")) {                    Plotly.newPlot(                        "3eed2219-dfb6-4715-8364-2c6cf97de3e7",                        [{"customdata": [["</br>id: 0</br>prediction: 343218.406</br>age: -1.5078633764688143</br></br>age_after_renovation: -1.3164858119554652</br>age_after_renovation_cat: -1.2652907056056013</br>age_after_renovation_sq: -0.8450910013620356</br>age_cat: -1.3206624854918618</br>age_sq: -0.8856672777922154</br>basement_bool: -0.8018175855622736</br>bathrooms: 0.5062576549952225</br>bathrooms_sq: 0.3262209312123226</br>bedrooms: -0.3903299143463248</br>bedrooms_sq: -0.3022200463518405</br>condition: -0.6306127701385122</br>... too many variables"], ["</br>id: 0</br>prediction: 343218.406</br>age: -1.468560186676714</br></br>age_after_renovation: -1.3164858119554652</br>age_after_renovation_cat: -1.2652907056056013</br>age_after_renovation_sq: -0.8450910013620356</br>age_cat: -1.3206624854918618</br>age_sq: -0.8856672777922154</br>basement_bool: -0.8018175855622736</br>bathrooms: 0.5062576549952225</br>bathrooms_sq: 0.3262209312123226</br>bedrooms: -0.3903299143463248</br>bedrooms_sq: -0.3022200463518405</br>condition: -0.6306127701385122</br>... too many variables"], ["</br>id: 0</br>prediction: 343218.406</br>age: -1.4292569968846136</br></br>age_after_renovation: -1.3164858119554652</br>age_after_renovation_cat: -1.2652907056056013</br>age_after_renovation_sq: -0.8450910013620356</br>age_cat: -1.3206624854918618</br>age_sq: -0.8856672777922154</br>basement_bool: -0.8018175855622736</br>bathrooms: 0.5062576549952225</br>bathrooms_sq: 0.3262209312123226</br>bedrooms: -0.3903299143463248</br>bedrooms_sq: -0.3022200463518405</br>condition: -0.6306127701385122</br>... too many variables"], ["</br>id: